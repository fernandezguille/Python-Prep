# %% [markdown]
# 1) Crear la clase vehículo que contenga los atributos:<br>
# Color<br>
# Si es moto, auto, camioneta ó camión<br>
# Cilindrada del motor

# %%
class Vehiculo:
    def __init__(self, color, tipo, c_motor):
        self.color = color
        self.tipo = tipo
        self.c_motor = c_motor

# %% [markdown]
# 2) A la clase Vehiculo creada en el punto 1, agregar los siguientes métodos:<br>
# Acelerar<br>
# Frenar<br>
# Doblar<br>

# %%
class Vehiculo:
    
    def __init__(self, color, tipo, c_motor):
        self.color = color
        self.tipo = tipo
        self.c_motor = c_motor
        self.velocidad = 0
        self.direccion = 0
    
    def Acelerar(self, cambio_vel):
        self.velocidad += cambio_vel

    def Frenar(self, cambio_vel):
        self.velocidad -= cambio_vel
    
    def Doblar(self, angulo):
        self.direccion += angulo

# %% [markdown]
# 3) Instanciar 3 objetos de la clase vehículo y ejecutar sus métodos, probar luego el resultado

# %%
Auto1 = Vehiculo("Gris plata", "auto", "2.0")
Auto2 = Vehiculo("Negro", "moto", "0.150")
Auto3 = Vehiculo("Blanco", "camion", "15.0")
Auto1.Acelerar(80)
Auto2.Acelerar(60)
Auto3.Acelerar(40)
print(f"La velocidad del {Auto1.tipo} {Auto1.color} es {Auto1.velocidad}, la velocidad del {Auto2.tipo} {Auto2.color} es {Auto2.velocidad}, la velocidad del {Auto3.tipo} {Auto3.color} es {Auto3.velocidad}")
Auto1.Frenar(70)
print(f"Ahora el {Auto1.tipo} {Auto2.color} cambio su velocidad a {Auto1.velocidad}")
Auto3.Doblar(90)
print(f"El {Auto3.tipo} {Auto3.color} cambio su direccion {Auto3.direccion} grados")

# %% [markdown]
# 4) Agregar a la clase Vehiculo, un método que muestre su estado, es decir, a que velocidad se encuentra y su dirección. Y otro método que muestre color, tipo y cilindrada

# %%
class Vehiculo:
    
    def __init__(self, color, tipo, c_motor):
        self.color = color
        self.tipo = tipo
        self.c_motor = c_motor
        self.velocidad = 0
        self.direccion = 0
    
    def Acelerar(self, cambio_vel):
        self.velocidad += cambio_vel

    def Frenar(self, cambio_vel):
        self.velocidad -= cambio_vel
    
    def Doblar(self, angulo):
        self.direccion += angulo

    def Estado(self):
        print(f"El {self.tipo} viaja a {self.velocidad} km/h en direccion {self.direccion} al Norte")

    def Caracteristicas(self):
        print(f"El {self.tipo} es de color {self.color} con un motor de {self.c_motor}")

# %%
Auto1 = Vehiculo("Gris plata", "auto", "2.0")
Auto1.Estado()
Auto1.Acelerar(80)
Auto1.Doblar(90)
Auto1.Estado()
Auto1.Caracteristicas()

# %% [markdown]
# 5) Crear una clase que permita utilizar las funciones creadas en la práctica del módulo 6<br>
# Verifica_Primo<br>
# Valor modal<br>
# Conversion_grados<br>
# Factorial<br>

# %%
class Utilidades:
    
    def __init__(self):
        pass

    def es_primo(self, numero):
        primo = True
        for n in range(2,(numero//2+1)):
            if numero % n == 0:
                primo = False
                break
        return(primo)

    def moda(self, lista, orden=True):
        '''
        Esta función devuelve el valor modal y recibe de parámetros dos valores:
        1-Una lista de números
        2-Verdadero (por defecto) por si se requiere el mínimo de los más repetidos, o Falso si se requiere el máximo
        '''
        if len(lista) == 0:
            return (None)
        repeticiones = 0
        indice = 0
        if (orden):
            lista.sort(reverse=True)
        else:
            lista.sort()
        for elemento in lista:
            if lista.count(elemento) >= repeticiones:
                repeticiones = lista.count(elemento)
                indice = lista.index(elemento)
        return (lista[indice], repeticiones)

    def conversor(self, valor, origen, destino):
        if (type(valor) != float and type(valor) != int):
            return ("El valor debe ser un numero")
        if (origen == "C"):
            if (destino == "C"):
                temperatura = valor
            elif (destino == "F"):
                temperatura = round(valor * 9 / 5 + 32, 2)
            elif (destino == "K"):
                temperatura = valor + 273.15
            else:
                return ("El parametro de destino debe ser C, F o K")
        elif (origen == "F"):
            if (destino == "F"):
                temperatura = valor
            elif (destino == "C"):
                temperatura = round((valor - 32) * 5 / 9,2)
            elif (destino == "K"):
                temperatura = round((valor - 32) * 5 / 9 + 273.15, 2)
            else:
                return ("El parametro de destino debe ser C, F o K")
        elif (origen == "K"):
            if (destino == "K"):
                temperatura = valor
            elif (destino == "F"):
                temperatura = round(valor * 9 / 5 + 305.15, 2)
            elif (destino == "C"):
                temperatura = valor - 273.15
            else:
                return ("El parametro de destino debe ser C, F o K")
        else:
            return ("El parametro de origen debe ser C, F o K")
        return temperatura

    def factorial(self, numero):
        if (type(numero) != int):
            return ("Se debe ingresar un numero entero positivo")
        elif (numero < 0):
            return ("El número debe ser un entero positivo")
        elif (numero > 1):
            numero = numero * self.factorial(numero - 1)
        elif (numero == 0):
            numero = 1
        return (numero)

# %% [markdown]
# 6) Probar las funciones incorporadas en la clase del punto 5

# %%
Util = Utilidades()
for numero in range (3,8):
    valor = (Util.es_primo(numero))
    print(f"El numero {numero} es primo? {valor}")
fact = (Util.factorial(numero))
print(fact)
temp = (Util.conversor(numero,"C","F"))
print(temp)
temp = (Util.conversor(fact,"F","C"))
print(temp)
lista1 = ["rojo", "verde", "azul", "rojo"]
moda, repe = Util.moda(lista1)
print(f"La moda de la lista {lista1} es {moda} con {repe} repeticiones")

# %% [markdown]
# 7) Es necesario que la clase creada en el punto 5 contenga una lista, sobre la cual se aplquen las funciones incorporadas

# %%
class Utilidades:
    
    def __init__(self, lista_numeros):
        self.lista = lista_numeros
        self.lista_sin_duplicados = []
        for elemento in lista_numeros:
            if not(elemento in self.lista_sin_duplicados):
                self.lista_sin_duplicados.append(elemento)

    def __es_primo(self, numero):
        primo = True
        for n in range(2,(numero//2+1)):
            if numero % n == 0:
                primo = False
                break
        return(primo)

    def es_primo(self):
        for elemento in self.lista_sin_duplicados:
            if (self.__es_primo(elemento)):
                print(f"El numero {elemento} SI es primo")
            else:
                print(f"El numero {elemento} NO es primo")

    def __moda(self, lista, orden=True):
        if len(lista) == 0:
            return (None)
        repeticiones = 0
        indice = 0
        if (orden):
            lista.sort(reverse=True)
        else:
            lista.sort()
        for elemento in lista:
            if lista.count(elemento) >= repeticiones:
                repeticiones = lista.count(elemento)
                indice = lista.index(elemento)
        return (lista[indice], repeticiones)

    def moda(self, orden=True):
        if (orden):
            nro, repes = self.__moda(self.lista)
            print(f"El valor modal minimo es {nro} y se repite {repes} veces")
        else:
            nro, repes = self.__moda(self.lista, False)
            print(f"El valor modal maximo es {nro} y se repite {repes} veces")

    def __conversor(self, valor, origen, destino):
        if (type(valor) != float and type(valor) != int):
            return ("El valor debe ser un numero")
        if (origen == "C"):
            if (destino == "C"):
                temperatura = valor
            elif (destino == "F"):
                temperatura = round(valor * 9 / 5 + 32, 2)
            elif (destino == "K"):
                temperatura = valor + 273.15
            else:
                return ("El parametro de destino debe ser C, F o K")
        elif (origen == "F"):
            if (destino == "F"):
                temperatura = valor
            elif (destino == "C"):
                temperatura = round((valor - 32) * 5 / 9,2)
            elif (destino == "K"):
                temperatura = round((valor - 32) * 5 / 9 + 273.15, 2)
            else:
                return ("El parametro de destino debe ser C, F o K")
        elif (origen == "K"):
            if (destino == "K"):
                temperatura = valor
            elif (destino == "F"):
                temperatura = round(valor * 9 / 5 + 305.15, 2)
            elif (destino == "C"):
                temperatura = valor - 273.15
            else:
                return ("El parametro de destino debe ser C, F o K")
        else:
            return ("El parametro de origen debe ser C, F o K")
        return temperatura

    def conversor(self, origen, destino):
        for elemento in self.lista_sin_duplicados:
            print(f"{elemento} grados {origen} son equivalentes a {self.__conversor(elemento, origen, destino)} grados {destino}")
    
    def __factorial(self, numero):
        if (type(numero) != int):
            return ("Se debe ingresar un numero entero positivo")
        elif (numero < 0):
            return ("El número debe ser un entero positivo")
        elif (numero > 1):
            numero = numero * self.__factorial(numero - 1)
        elif (numero == 0):
            numero = 1
        return (numero)
    
    def factorial(self):
        for elemento in self.lista_sin_duplicados:
            print(f"{elemento}! = {self.__factorial(elemento)}")

# %%
Util = Utilidades([1,1,2,5,8,8,9,11,15,16,16,16,18,20,8])
Util.factorial()
Util.conversor("C","F")  
Util.moda()
Util.moda(False)
Util.es_primo()

# %% [markdown]
# 8) Crear un archivo .py aparte y ubicar allí la clase generada en el punto anterior. Luego realizar la importación del módulo y probar alguna de sus funciones

# %%
from Utilidades import *
Herramienta = Utilidades([1,1,1,2,5,8,8,9,11,7,7,7,7,15,16,16,16,18,20,8])
Herramienta.factorial()
Herramienta.conversor("F","C")
Herramienta.moda()
Herramienta.moda(False)
Herramienta.es_primo()
# Out:
# 1! = 1
# 2! = 2
# 5! = 120
# 8! = 40320
# 9! = 362880
# 11! = 39916800
# 7! = 5040
# 15! = 1307674368000
# 16! = 20922789888000
# 18! = 6402373705728000
# 20! = 2432902008176640000
# 1 grados F son equivalentes a -17.22 grados C
# 2 grados F son equivalentes a -16.67 grados C
# 5 grados F son equivalentes a -15.0 grados C
# 8 grados F son equivalentes a -13.33 grados C
# 9 grados F son equivalentes a -12.78 grados C
# 11 grados F son equivalentes a -11.67 grados C
# 7 grados F son equivalentes a -13.89 grados C
# 15 grados F son equivalentes a -9.44 grados C
# 16 grados F son equivalentes a -8.89 grados C
# 18 grados F son equivalentes a -7.78 grados C
# 20 grados F son equivalentes a -6.67 grados C
# 1 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 2 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 5 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 8 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 9 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 11 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 7 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 15 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 16 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 18 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# 20 grados K son equivalentes a El parametro de destino debe ser C, F o K grados Celsius
# El valor modal minimo es 7 y se repite 4 veces
# El valor modal maximo es 7 y se repite 4 veces
# El numero 1 SI es primo
# El numero 2 SI es primo
# El numero 5 SI es primo
# El numero 8 NO es primo
# El numero 9 NO es primo
# El numero 11 SI es primo
# El numero 7 SI es primo
# El numero 15 NO es primo
# El numero 16 NO es primo
# El numero 18 NO es primo
# El numero 20 NO es primo
